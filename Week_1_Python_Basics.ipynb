# %% [markdown]
# <a href="https://colab.research.google.com/github/deacoki/ai-mastery-2026/blob/main/Week_1_Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Kirk"
print(f"Hello, {name}! I start my AI agent journey today, April 1 2026 🚀")

age = 50  # Change this to your actual age if you want
print(f"In 7 months I will be building real AI agents that save me hours every week.")
# Out:
# Hello, Kirk! I start my AI agent journey today, April 1 2026 🚀
# In 7 months I will be building real AI agents that save me hours every week.

# %%
name = input ("Enter your name: ")
age = input ("Enter your age: ")
print ("Hello " + name + "! " "You are " + age)
# Out:
# Enter your name: Kirk
# Enter your age: 50
# Hello Kirk! You are 50

# %%
num1 = float (input ("Enter first number: "))
num2 = input ("Enter another number: ")
result = float(num1) + float(num2)
print(result)
# Out:
# Enter a number: 4.6
# Enter another number: 7.3
# 11.899999999999999

# %%
num1 = float(input ("Enter first number: "))
op = input("Enter operator: ")
num2 = float(input ("Enter second number: "))

if op == "+":
  print(num1 + num2)
elif op == "-":
  print(num1 - num2)
elif op == "/":
  print(num1 / num2)
elif op == "*":
  print(num1 * num2)
else:
  print("Invalid operator")
# Out:
# Enter first number: 5
# Enter operator: t
# Enter second number: 4
# Invalid operator

# %%
daily_tasks = ["Check email", "Study Python", "Plan AI agent", "Exercise", "Review notes"]
print(daily_tasks)
print("First task:", daily_tasks[0])   # indexing starts at 0
print("Last task:", daily_tasks[-1])
# Out:
# ['Check email', 'Study Python', 'Plan AI agent', 'Exercise', 'Review notes']
# First task: Check email
# Last task: Review notes

# %%
for task in daily_tasks:
    print(f"Today I will: {task}")
# Out:
# Today I will: Check email
# Today I will: Study Python
# Today I will: Plan AI agent
# Today I will: Exercise
# Today I will: Review notes

# %%
temperature = 10   # Change this number to test different cases
if temperature > 70:
    print("It's warm — good day for a walk!")
elif temperature > 50:
    print("It's mild — maybe wear a light jacket.")
else:
    print("It's cool — better wear something warmer.")
# Out:
# It's cool — better wear something warmer.

# %%
count = 1
while count <= 5:
    print(f"Loop iteration {count}")
    count = count + 1   # Important: increase count so it eventually stops
# Out:
# Loop iteration 1
# Loop iteration 2
# Loop iteration 3
# Loop iteration 4
# Loop iteration 5
